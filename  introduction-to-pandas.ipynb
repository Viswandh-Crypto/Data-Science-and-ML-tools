# %%
import pandas as pd

# %%
# 2 main datatypes
series = pd.Series(["BMW", "Toyoto", "Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyoto
# 2     Honda
# dtype: object

# %%
# series = 1-dimensional

# %%
colours = pd.Series(["Red", "Blue", "White"])
colours
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
# DataFrame = 2-dimensional
car_data = pd.DataFrame({"Car make": series, "colours": colours})
car_data
# Out:
#   Car make colours
# 0      BMW     Red
# 1   Toyoto    Blue
# 2    Honda   White

# %%
# Import data
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Exporting a dataframe
car_sales.to_csv("exported-car-sales.csv", index=False)

# %%
exported_car_sales = pd.read_csv("exported-car-sales.csv")
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe data

# %%
# Attribute
car_sales.dtypes

# Function
#car_sales.to_csv()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
car_sales.mean(numeric_only=True)
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_prices = pd.Series([3000, 1500, 111250])
car_prices.mean()
# Out:
# np.float64(38583.333333333336)

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# np.int64(40)

# %%
len(car_sales)
# Out:
# 10

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Viewing and Selecting data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales.tail(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# .loc & .iloc (loc = location) loc refers to index
animals = pd.Series(["cat", "dog", "bird", "panda", "snake"],
                   index=[0, 3, 9, 8, 3])

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.loc[9]
# Out:
# 'bird'

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
# .iloc refers to position
animals.iloc[3]
# Out:
# 'panda'

# %%
# .loc refers to index
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: object

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales.head(4)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
car_sales.Odometer (KM)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9960\240837061.py in ?()
# ----> 1 car_sales.Odometer (KM)
#
# ~\OneDrive\Desktop\sample_projects_1\env\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Odometer'

# %%
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# Groupby
car_sales.groupby(["Make"]).mean(numeric_only =True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
car_sales["Odometer (KM)"].plot()
plt.show()

# %%
car_sales.plot(x="Make", y="Odometer (KM)")
plt.show()

# %%
car_sales["Odometer (KM)"].hist()
plt.show()

# %%
car_sales["Price"].dtype
# Out:
# dtype('O')

# %%
car_sales["Price"].plot().astype(int)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[356], line 1
# ----> 1 car_sales["Price"].plot().astype(int)
#       2 plt.show()
#
# AttributeError: 'Axes' object has no attribute 'astype'

# %%
# another line for below is car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '', regex=True).astype(int)
# the above line for says cleary that replce the '$', ',', '.' symbols

# %%
car_sales["Price"] = car_sales["Price"].str.replace("[$,.]", "", regex=True)

# %%
car_sales["Price"]
# Out:
# 0     400000
# 1     500000
# 2     700000
# 3    2200000
# 4     350000
# 5     450000
# 6     750000
# 7     700000
# 8     625000
# 9     970000
# Name: Price, dtype: object

# %%
car_sales["Price"] = car_sales["Price"].str[:-2]

# %%
car_sales["Price"]
# Out:
# 0     4000
# 1     5000
# 2     7000
# 3    22000
# 4     3500
# 5     4500
# 6     7500
# 7     7000
# 8     6250
# 9     9700
# Name: Price, dtype: object

# %%
car_sales["Price"] = car_sales["Price"].astype(int)

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %% [markdown]
# ## Manipulating Data

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].mean()
# Out:
# np.float64(92302.66666666667)

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped = car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped.to_csv("car-sales-missing-dropped.csv")

# %%
# Column from series
seats_column = pd.Series([5, 5, 5, 5, 5,])

# New column called seats
car_sales["Seats"] = seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White   36631.591797      4   4000    5.0             7.5
# 1   honda    Red   21459.716797      4   5000    5.0             9.2
# 2  toyota   Blue    7946.533203      3   7000    5.0             5.0
# 3     bmw  Black    2729.248047      5  22000    5.0             9.6
# 4  nissan  White   52025.146484      4   3500    5.0             8.7
# 5  toyota  Green   24221.923828      4   4500    NaN             4.7
# 6   honda   Blue   11156.738281      4   7500    NaN             7.6
# 7   honda   Blue   13363.769531      4   7000    NaN             8.7
# 8  toyota  White   14648.437500      4   6250    NaN             3.0
# 9  nissan  White    7714.843750      4   9700    NaN             4.5
#
#    Number of wheels  Passed road saftey
# 0                 4                True
# 1                 4                True
# 2                 4                True
# 3                 4                True
# 4                 4                True
# 5                 4                True
# 6                 4                True
# 7                 4                True
# 8                 4                True
# 9                 4                True

# %%
car_sales["Seats"].fillna(5)
# Out:
# 0    5.0
# 1    5.0
# 2    5.0
# 3    5.0
# 4    5.0
# 5    5.0
# 6    5.0
# 7    5.0
# 8    5.0
# 9    5.0
# Name: Seats, dtype: float64

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White   36631.591797      4   4000    5.0             7.5
# 1   honda    Red   21459.716797      4   5000    5.0             9.2
# 2  toyota   Blue    7946.533203      3   7000    5.0             5.0
# 3     bmw  Black    2729.248047      5  22000    5.0             9.6
# 4  nissan  White   52025.146484      4   3500    5.0             8.7
# 5  toyota  Green   24221.923828      4   4500    NaN             4.7
# 6   honda   Blue   11156.738281      4   7500    NaN             7.6
# 7   honda   Blue   13363.769531      4   7000    NaN             8.7
# 8  toyota  White   14648.437500      4   6250    NaN             3.0
# 9  nissan  White    7714.843750      4   9700    NaN             4.5
#
#    Number of wheels  Passed road saftey
# 0                 4                True
# 1                 4                True
# 2                 4                True
# 3                 4                True
# 4                 4                True
# 5                 4                True
# 6                 4                True
# 7                 4                True
# 8                 4                True
# 9                 4                True

# %%
# column from Python list 
fuel_economy = [7.5, 9.2, 5.0, 9.6, 8.7, 4.7, 7.6, 8.7, 3.0, 4.5]
car_sales["Fuel per 100KM"] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White   36631.591797      4   4000    5.0             7.5
# 1   honda    Red   21459.716797      4   5000    5.0             9.2
# 2  toyota   Blue    7946.533203      3   7000    5.0             5.0
# 3     bmw  Black    2729.248047      5  22000    5.0             9.6
# 4  nissan  White   52025.146484      4   3500    5.0             8.7
# 5  toyota  Green   24221.923828      4   4500    NaN             4.7
# 6   honda   Blue   11156.738281      4   7500    NaN             7.6
# 7   honda   Blue   13363.769531      4   7000    NaN             8.7
# 8  toyota  White   14648.437500      4   6250    NaN             3.0
# 9  nissan  White    7714.843750      4   9700    NaN             4.5
#
#    Number of wheels  Passed road saftey
# 0                 4                True
# 1                 4                True
# 2                 4                True
# 3                 4                True
# 4                 4                True
# 5                 4                True
# 6                 4                True
# 7                 4                True
# 8                 4                True
# 9                 4                True

# %%
car_sales["Total fuel used (L)"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel per 100KM"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White   36631.591797      4   4000    5.0             7.5
# 1   honda    Red   21459.716797      4   5000    5.0             9.2
# 2  toyota   Blue    7946.533203      3   7000    5.0             5.0
# 3     bmw  Black    2729.248047      5  22000    5.0             9.6
# 4  nissan  White   52025.146484      4   3500    5.0             8.7
# 5  toyota  Green   24221.923828      4   4500    NaN             4.7
# 6   honda   Blue   11156.738281      4   7500    NaN             7.6
# 7   honda   Blue   13363.769531      4   7000    NaN             8.7
# 8  toyota  White   14648.437500      4   6250    NaN             3.0
# 9  nissan  White    7714.843750      4   9700    NaN             4.5
#
#    Number of wheels  Passed road saftey  Total fuel used (L)
# 0                 4                True          2747.369385
# 1                 4                True          1974.293945
# 2                 4                True           397.326660
# 3                 4                True           262.007812
# 4                 4                True          4526.187744
# 5                 4                True          1138.430420
# 6                 4                True           847.912109
# 7                 4                True          1162.647949
# 8                 4                True           439.453125
# 9                 4                True           347.167969

# %%
# Create a column from a single value
car_sales["Number of wheels"] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White   36631.591797      4   4000    5.0             7.5
# 1   honda    Red   21459.716797      4   5000    5.0             9.2
# 2  toyota   Blue    7946.533203      3   7000    5.0             5.0
# 3     bmw  Black    2729.248047      5  22000    5.0             9.6
# 4  nissan  White   52025.146484      4   3500    5.0             8.7
# 5  toyota  Green   24221.923828      4   4500    NaN             4.7
# 6   honda   Blue   11156.738281      4   7500    NaN             7.6
# 7   honda   Blue   13363.769531      4   7000    NaN             8.7
# 8  toyota  White   14648.437500      4   6250    NaN             3.0
# 9  nissan  White    7714.843750      4   9700    NaN             4.5
#
#    Number of wheels  Passed road saftey  Total fuel used (L)
# 0                 4                True          2747.369385
# 1                 4                True          1974.293945
# 2                 4                True           397.326660
# 3                 4                True           262.007812
# 4                 4                True          4526.187744
# 5                 4                True          1138.430420
# 6                 4                True           847.912109
# 7                 4                True          1162.647949
# 8                 4                True           439.453125
# 9                 4                True           347.167969

# %%
car_sales["Passed road saftey"] = True
car_sales.dtypes
# Out:
# Make                    object
# Colour                  object
# Odometer (KM)          float64
# Doors                    int64
# Price                    int64
# Seats                  float64
# Fuel per 100KM         float64
# Number of wheels         int64
# Passed road saftey        bool
# Total fuel used (L)    float64
# dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White   36631.591797      4   4000    5.0             7.5
# 1   honda    Red   21459.716797      4   5000    5.0             9.2
# 2  toyota   Blue    7946.533203      3   7000    5.0             5.0
# 3     bmw  Black    2729.248047      5  22000    5.0             9.6
# 4  nissan  White   52025.146484      4   3500    5.0             8.7
# 5  toyota  Green   24221.923828      4   4500    NaN             4.7
# 6   honda   Blue   11156.738281      4   7500    NaN             7.6
# 7   honda   Blue   13363.769531      4   7000    NaN             8.7
# 8  toyota  White   14648.437500      4   6250    NaN             3.0
# 9  nissan  White    7714.843750      4   9700    NaN             4.5
#
#    Number of wheels  Passed road saftey  Total fuel used (L)
# 0                 4                True          2747.369385
# 1                 4                True          1974.293945
# 2                 4                True           397.326660
# 3                 4                True           262.007812
# 4                 4                True          4526.187744
# 5                 4                True          1138.430420
# 6                 4                True           847.912109
# 7                 4                True          1162.647949
# 8                 4                True           439.453125
# 9                 4                True           347.167969

# %%
car_sales = car_sales.drop("Total fuel used (L)", axis=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White   36631.591797      4   4000    5.0             7.5
# 1   honda    Red   21459.716797      4   5000    5.0             9.2
# 2  toyota   Blue    7946.533203      3   7000    5.0             5.0
# 3     bmw  Black    2729.248047      5  22000    5.0             9.6
# 4  nissan  White   52025.146484      4   3500    5.0             8.7
# 5  toyota  Green   24221.923828      4   4500    NaN             4.7
# 6   honda   Blue   11156.738281      4   7500    NaN             7.6
# 7   honda   Blue   13363.769531      4   7000    NaN             8.7
# 8  toyota  White   14648.437500      4   6250    NaN             3.0
# 9  nissan  White    7714.843750      4   9700    NaN             4.5
#
#    Number of wheels  Passed road saftey
# 0                 4                True
# 1                 4                True
# 2                 4                True
# 3                 4                True
# 4                 4                True
# 5                 4                True
# 6                 4                True
# 7                 4                True
# 8                 4                True
# 9                 4                True

# %%
car_sales_shuffled = car_sales.sample(frac=1)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 3     bmw  Black    2729.248047      5  22000    5.0             9.6
# 1   honda    Red   21459.716797      4   5000    5.0             9.2
# 6   honda   Blue   11156.738281      4   7500    NaN             7.6
# 8  toyota  White   14648.437500      4   6250    NaN             3.0
# 7   honda   Blue   13363.769531      4   7000    NaN             8.7
# 0  toyota  White   36631.591797      4   4000    5.0             7.5
# 5  toyota  Green   24221.923828      4   4500    NaN             4.7
# 2  toyota   Blue    7946.533203      3   7000    5.0             5.0
# 4  nissan  White   52025.146484      4   3500    5.0             8.7
# 9  nissan  White    7714.843750      4   9700    NaN             4.5
#
#    Number of wheels  Passed road saftey
# 3                 4                True
# 1                 4                True
# 6                 4                True
# 8                 4                True
# 7                 4                True
# 0                 4                True
# 5                 4                True
# 2                 4                True
# 4                 4                True
# 9                 4                True

# %%
# Only select 20% of data
car_sales_shuffled.sample(frac=0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 2  toyota   Blue    7946.533203      3   7000    5.0             5.0
# 6   honda   Blue   11156.738281      4   7500    NaN             7.6
#
#    Number of wheels  Passed road saftey
# 2                 4                True
# 6                 4                True

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 3     bmw  Black    2729.248047      5  22000    5.0             9.6
# 1   honda    Red   21459.716797      4   5000    5.0             9.2
# 6   honda   Blue   11156.738281      4   7500    NaN             7.6
# 8  toyota  White   14648.437500      4   6250    NaN             3.0
# 7   honda   Blue   13363.769531      4   7000    NaN             8.7
# 0  toyota  White   36631.591797      4   4000    5.0             7.5
# 5  toyota  Green   24221.923828      4   4500    NaN             4.7
# 2  toyota   Blue    7946.533203      3   7000    5.0             5.0
# 4  nissan  White   52025.146484      4   3500    5.0             8.7
# 9  nissan  White    7714.843750      4   9700    NaN             4.5
#
#    Number of wheels  Passed road saftey
# 3                 4                True
# 1                 4                True
# 6                 4                True
# 8                 4                True
# 7                 4                True
# 0                 4                True
# 5                 4                True
# 2                 4                True
# 4                 4                True
# 9                 4                True

# %%
car_sales_shuffled.reset_index(drop=True, inplace=True)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0     bmw  Black    2729.248047      5  22000    5.0             9.6
# 1   honda    Red   21459.716797      4   5000    5.0             9.2
# 2   honda   Blue   11156.738281      4   7500    NaN             7.6
# 3  toyota  White   14648.437500      4   6250    NaN             3.0
# 4   honda   Blue   13363.769531      4   7000    NaN             8.7
# 5  toyota  White   36631.591797      4   4000    5.0             7.5
# 6  toyota  Green   24221.923828      4   4500    NaN             4.7
# 7  toyota   Blue    7946.533203      3   7000    5.0             5.0
# 8  nissan  White   52025.146484      4   3500    5.0             8.7
# 9  nissan  White    7714.843750      4   9700    NaN             4.5
#
#    Number of wheels  Passed road saftey
# 0                 4                True
# 1                 4                True
# 2                 4                True
# 3                 4                True
# 4                 4                True
# 5                 4                True
# 6                 4                True
# 7                 4                True
# 8                 4                True
# 9                 4                True

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White   36631.591797      4   4000    5.0             7.5
# 1   honda    Red   21459.716797      4   5000    5.0             9.2
# 2  toyota   Blue    7946.533203      3   7000    5.0             5.0
# 3     bmw  Black    2729.248047      5  22000    5.0             9.6
# 4  nissan  White   52025.146484      4   3500    5.0             8.7
# 5  toyota  Green   24221.923828      4   4500    NaN             4.7
# 6   honda   Blue   11156.738281      4   7500    NaN             7.6
# 7   honda   Blue   13363.769531      4   7000    NaN             8.7
# 8  toyota  White   14648.437500      4   6250    NaN             3.0
# 9  nissan  White    7714.843750      4   9700    NaN             4.5
#
#    Number of wheels  Passed road saftey
# 0                 4                True
# 1                 4                True
# 2                 4                True
# 3                 4                True
# 4                 4                True
# 5                 4                True
# 6                 4                True
# 7                 4                True
# 8                 4                True
# 9                 4                True

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x: x/ 1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White   22894.744873      4   4000    5.0             7.5
# 1   honda    Red   13412.322998      4   5000    5.0             9.2
# 2  toyota   Blue    4966.583252      3   7000    5.0             5.0
# 3     bmw  Black    1705.780029      5  22000    5.0             9.6
# 4  nissan  White   32515.716553      4   3500    5.0             8.7
# 5  toyota  Green   15138.702393      4   4500    NaN             4.7
# 6   honda   Blue    6972.961426      4   7500    NaN             7.6
# 7   honda   Blue    8352.355957      4   7000    NaN             8.7
# 8  toyota  White    9155.273438      4   6250    NaN             3.0
# 9  nissan  White    4821.777344      4   9700    NaN             4.5
#
#    Number of wheels  Passed road saftey
# 0                 4                True
# 1                 4                True
# 2                 4                True
# 3                 4                True
# 4                 4                True
# 5                 4                True
# 6                 4                True
# 7                 4                True
# 8                 4                True
# 9                 4                True

# %%
# Try it, run your code
# Search for it
# Try again
# Ask
